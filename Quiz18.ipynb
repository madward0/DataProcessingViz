# %% [markdown]
# ## Quiz 18: Dates
#
# ####Madison Ward

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Data_Sets/IOT-temp.csv"
df = pd.read_csv(url)

df['noted_date'] = pd.to_datetime(df['noted_date'], format='%d-%m-%Y %H:%M')
display(df.head())
# Out:
#                                     id  room_id/id          noted_date  temp  \
# 0  __export__.temp_log_196134_bd201015  Room Admin 2018-12-08 09:30:00    29
# 1  __export__.temp_log_196131_7bca51bc  Room Admin 2018-12-08 09:30:00    29
# 2  __export__.temp_log_196127_522915e3  Room Admin 2018-12-08 09:29:00    41
# 3  __export__.temp_log_196128_be0919cf  Room Admin 2018-12-08 09:29:00    41
# 4  __export__.temp_log_196126_d30b72fb  Room Admin 2018-12-08 09:29:00    31
#
#   out/in
# 0     In
# 1     In
# 2    Out
# 3    Out
# 4     In

# %% [markdown]
# 2. Min and max

# %%
min_date = df['noted_date'].min()
max_date = df['noted_date'].max()

min_date, max_date
# Out:
# (Timestamp('2018-07-28 07:06:00'), Timestamp('2018-12-08 09:30:00'))

# %% [markdown]
# 3. Largest time interval

# %%
df = df.sort_values('noted_date')

df['time_diff'] = df['noted_date'].diff()

largest_interval = df['time_diff'].max()

largest_interval
# Out:
# Timedelta('11 days 13:38:00')

# %% [markdown]
# 4. Average Datetime

# %%
avg_datetime = df['noted_date'].mean()

avg_datetime
# Out:
# Timestamp('2018-10-07 05:10:38.821179136')

# %% [markdown]
# 5. Avg temp on 9/11/2018
#
# I didn't see any logs on 09-11-2018...

# %%
df[(df['noted_date'].dt.date == pd.to_datetime('09-11-2018', dayfirst=True).date()) & (df['out/in'] == 'Out')]['temp'].mean()
# Out:
# nan
