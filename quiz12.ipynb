# %% [markdown]
# ## Quiz 12
#
# ### Madison Ward

# %%
import pandas as pd
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_Marvel_Cinematic_Universe_films"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

# %%
tables = pd.read_html(response.text)

len(tables)
# Out:
# /tmp/ipykernel_329/3317296139.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)
# 41

# %%
mcu_films = tables[0]

mcu_films.head()

mcu_films
# Out:
#                       Marvel Cinematic Universe films  \
# 0   Artwork for "The Infinity Saga Collector's Edi...
# 1                                            Based on
# 2                                         Produced by
# 3                                            Starring
# 4                                Production companies
# 5                                      Distributed by
# 6                                        Release date
# 7                                             Country
# 8                                            Language
# 9                                              Budget
# 10                                         Box office
#
#                     Marvel Cinematic Universe films.1
# 0   Artwork for "The Infinity Saga Collector's Edi...
# 1               Characters published by Marvel Comics
# 2   Kevin Feige[a] Avi Arad (IM & TIH) Gale Anne H...
# 3               Marvel Cinematic Universe film actors
# 4   Marvel Studios Valhalla Motion Pictures (TIH) ...
# 5   Paramount Pictures (2008–11) Universal Picture...
# 6                                        2008–present
# 7                                       United States
# 8                                             English
# 9              Total (37 films): $7.239–7.724 billion
# 10                  Total (37 films): $32.487 billion

# %%
mcu_films.to_csv("mcu_films.csv", index=False)
